# %%
import requests

def make_request(append_url):
    base_url = "https://ridb.recreation.gov/api/v1/"
    response = requests.get(base_url + append_url, headers= {"apikey": api_key})
    response.raise_for_status()
    return response.json()

# %%
from fetch_aws_secret import fetch_aws_secret

# %%
eval(fetch_aws_secret(secret_name = "prod/recreationgov/apikey"))['RecreationGovAPIKey']
# Out:
# '30448a3a-b833-4151-af2c-e78d568a2486'

# %%
response = make_request("campsites?limit=1") 
response
# Out:
# {'RECDATA': [{'CampsiteID': '103039',
#    'FacilityID': '272094',
#    'CampsiteName': 'C01',
#    'CampsiteType': 'WALK TO',
#    'TypeOfUse': 'Overnight',
#    'Loop': 'COTTONWOOD CAMPGROUND (IA)',
#    'CampsiteAccessible': False,
#    'CampsiteReservable': True,
#    'CampsiteLongitude': -91.534226,
#    'CampsiteLatitude': 41.722275,
#    'CreatedDate': '2017-11-09',
#    'LastUpdatedDate': '2020-10-15',
#    'ATTRIBUTES': [{'AttributeName': 'Placed on Map', 'AttributeValue': '1'},
#     {'AttributeName': 'Capacity/Size Rating', 'AttributeValue': 'Single'},
#     {'AttributeName': 'Checkin Time', 'AttributeValue': '4:00 PM'},
#     {'AttributeName': 'Min Num of Vehicles', 'AttributeValue': '1'},
#     {'AttributeName': 'IS EQUIPMENT MANDATORY', 'AttributeValue': 'true'},
#     {'AttributeName': 'Grills/Fire Ring', 'AttributeValue': 'Y'},
#     {'AttributeName': 'Picnic Table', 'AttributeValue': 'Y'},
#     {'AttributeName': 'Shade', 'AttributeValue': 'Yes'},
# ...

# %%
response.raise_for_status()
# Out:
# Signature: response.raise_for_status()
# Docstring: Raises stored :class:`HTTPError`, if one occurred.
# File:      ~/Library/Python/3.8/lib/python/site-packages/requests/models.py
# Type:      method

# %%
contents['RECDATA']
# Out:
# [{'CampsiteID': '103039',
#   'FacilityID': '272094',
#   'CampsiteName': 'C01',
#   'CampsiteType': 'WALK TO',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'COTTONWOOD CAMPGROUND (IA)',
#   'CampsiteAccessible': False,
#   'CampsiteReservable': True,
#   'CampsiteLongitude': -91.534226,
#   'CampsiteLatitude': 41.722275,
#   'CreatedDate': '2017-11-09',
#   'LastUpdatedDate': '2020-10-15',
#   'ATTRIBUTES': [{'AttributeName': 'Placed on Map', 'AttributeValue': '1'},
#    {'AttributeName': 'Capacity/Size Rating', 'AttributeValue': 'Single'},
#    {'AttributeName': 'Checkin Time', 'AttributeValue': '4:00 PM'},
#    {'AttributeName': 'Min Num of Vehicles', 'AttributeValue': '1'},
#    {'AttributeName': 'IS EQUIPMENT MANDATORY', 'AttributeValue': 'true'},
#    {'AttributeName': 'Grills/Fire Ring', 'AttributeValue': 'Y'},
#    {'AttributeName': 'Picnic Table', 'AttributeValue': 'Y'},
#    {'AttributeName': 'Shade', 'AttributeValue': 'Yes'},
# ...

# %%
help(response)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
# ...
